# %% [markdown]
# # 1. Iris( Decision Tree/ Support Vector Machine (SVM)/ Logistic Regression)

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.11/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
import time
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pandas as pd
from ucimlrepo import fetch_ucirepo
from sklearn.neighbors import KNeighborsClassifier

# %%
# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Split into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Decision Tree ---
dt = DecisionTreeClassifier(random_state=42)

start = time.time()
dt.fit(X_train, y_train)
dt_train_time = time.time() - start

start = time.time()
y_pred_dt = dt.predict(X_test)
dt_predict_time = time.time() - start

acc_dt = accuracy_score(y_test, y_pred_dt)

# %%
print("Decision Tree Accuracy:", acc_dt)
print("Decision Tree Training Time: {:.6f} seconds".format(dt_train_time))
print("Decision Tree Prediction Time: {:.6f} seconds".format(dt_predict_time))
# Out:
# Decision Tree Accuracy: 1.0
# Decision Tree Training Time: 0.005627 seconds
# Decision Tree Prediction Time: 0.000570 seconds

# %%
# --- SVM ---
svm = SVC(kernel='rbf', random_state=42)

start = time.time()
svm.fit(X_train_scaled, y_train)
svm_train_time = time.time() - start

start = time.time()
y_pred_svm = svm.predict(X_test_scaled)
svm_predict_time = time.time() - start

acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
print("\nSVM Accuracy:", acc_svm)
print("SVM Training Time: {:.6f} seconds".format(svm_train_time))
print("SVM Prediction Time: {:.6f} seconds".format(svm_predict_time))
# Out:
# SVM Accuracy: 1.0
# SVM Training Time: 0.002822 seconds
# SVM Prediction Time: 0.000811 seconds

# %%
# --- Logistic Regression ---
lr = LogisticRegression(max_iter=200, random_state=42)

start = time.time()
lr.fit(X_train_scaled, y_train)
lr_train_time = time.time() - start

start = time.time()
y_pred_lr = lr.predict(X_test_scaled)
lr_predict_time = time.time() - start

acc_lr = accuracy_score(y_test, y_pred_lr)

# %%
print("\nLogistic Regression Accuracy:", acc_lr)
print("Logistic Regression Training Time: {:.6f} seconds".format(lr_train_time))
print("Logistic Regression Prediction Time: {:.6f} seconds".format(lr_predict_time))
# Out:
# Logistic Regression Accuracy: 1.0
# Logistic Regression Training Time: 0.017199 seconds
# Logistic Regression Prediction Time: 0.000559 seconds

# %%
# Evaluate models using 5-fold cross-validation
cv = 5
scores_dt = cross_val_score(dt, scaler.fit_transform(X), y, cv=cv)
scores_svm = cross_val_score(svm, scaler.fit_transform(X), y, cv=cv)
scores_lr = cross_val_score(lr, scaler.fit_transform(X), y, cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Decision Tree CV Accuracy:", scores_dt.mean())
print("SVM CV Accuracy:", scores_svm.mean())
print("Logistic Regression CV Accuracy:", scores_lr.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Decision Tree CV Accuracy: 0.9533333333333334
# SVM CV Accuracy: 0.9666666666666666
# Logistic Regression CV Accuracy: 0.9600000000000002

# %% [markdown]
# #2. Wine Dataset(Decision Tree/Support Vector Machine (SVM)/k-Nearest Neighbors (k-NN))

# %%
from sklearn.datasets import load_wine
wine = load_wine()
X = wine.data
y = wine.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Decision Tree ---
dt = DecisionTreeClassifier(random_state=42)

start = time.time()
dt.fit(X_train, y_train)
dt_train_time = time.time() - start

start = time.time()
y_pred_dt = dt.predict(X_test)
dt_predict_time = time.time() - start

acc_dt = accuracy_score(y_test, y_pred_dt)

# %%
# --- SVM ---
svm = SVC(kernel='rbf', random_state=42)

start = time.time()
svm.fit(X_train_scaled, y_train)
svm_train_time = time.time() - start

start = time.time()
y_pred_svm = svm.predict(X_test_scaled)
svm_predict_time = time.time() - start

acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
# --- knn ---
knn = KNeighborsClassifier()
start = time.time()
knn.fit(X_train_scaled, y_train)
knn_train_time = time.time() - start

start = time.time()
y_pred_knn = knn.predict(X_test_scaled)
knn_predict_time = time.time() - start

acc_knn = accuracy_score(y_test, y_pred_knn)

# %%
print("Wine Dataset Results:")

print("Decision Tree:")
print("  Accuracy:", acc_dt)
print("  Training Time: {:.6f} seconds".format(dt_train_time))
print("  Prediction Time: {:.6f} seconds".format(dt_predict_time))

print("\nSVM:")
print("  Accuracy:", acc_svm)
print("  Training Time: {:.6f} seconds".format(svm_train_time))
print("  Prediction Time: {:.6f} seconds".format(svm_predict_time))

print("\nk-Nearest Neighbors:")
print("  Accuracy:", acc_knn)
print("  Training Time: {:.6f} seconds".format(knn_train_time))
print("  Prediction Time: {:.6f} seconds".format(knn_predict_time))
# Out:
# Wine Dataset Results:
# Decision Tree:
#   Accuracy: 0.9629629629629629
#   Training Time: 0.003378 seconds
#   Prediction Time: 0.000578 seconds
#
# SVM:
#   Accuracy: 0.9814814814814815
#   Training Time: 0.003691 seconds
#   Prediction Time: 0.001092 seconds
#
# k-Nearest Neighbors:
#   Accuracy: 0.9629629629629629
#   Training Time: 0.002396 seconds
#   Prediction Time: 0.006320 seconds

# %%
cv = 5
scores_dt = cross_val_score(dt, scaler.fit_transform(X), y, cv=cv)
scores_svm = cross_val_score(svm, scaler.fit_transform(X), y, cv=cv)
scores_lr = cross_val_score(knn, scaler.fit_transform(X), y, cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Decision Tree CV Accuracy:", scores_dt.mean())
print("SVM CV Accuracy:", scores_svm.mean())
print("k-NN CV Accuracy:", scores_lr.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Decision Tree CV Accuracy: 0.8709523809523809
# SVM CV Accuracy: 0.9833333333333334
# k-NN CV Accuracy: 0.9550793650793651

# %% [markdown]
# # Wine Quality Dataset(Decision Tree/Support Vector Machine (SVM)/Linear Discriminant Analysis (LDA))

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.11/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
wine_quality = fetch_ucirepo(id=186)

X = wine_quality.data.features
y = wine_quality.data.targets

# %%
y.value_counts()
# Out:
# quality
# 6          2836
# 5          2138
# 7          1079
# 4           216
# 8           193
# 3            30
# 9             5
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Decision Tree ---
dt = DecisionTreeClassifier(random_state=42)

start = time.time()
dt.fit(X_train, y_train)
dt_train_time = time.time() - start

start = time.time()
y_pred_dt = dt.predict(X_test)
dt_predict_time = time.time() - start

acc_dt = accuracy_score(y_test, y_pred_dt)

# %%
# --- SVM ---
svm = SVC(kernel='rbf', random_state=42)

start = time.time()
svm.fit(X_train_scaled, y_train.values.ravel())
svm_train_time = time.time() - start

start = time.time()
y_pred_svm = svm.predict(X_test_scaled)
svm_predict_time = time.time() - start

acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
# --- LDA ---
lda = LinearDiscriminantAnalysis()
start = time.time()
lda.fit(X_train_scaled, y_train.values.ravel())
lda_train_time = time.time() - start

start = time.time()
y_pred_lda = lda.predict(X_test_scaled)
lda_predict_time = time.time() - start

acc_lda = accuracy_score(y_test, y_pred_lda)

# %%
print("Wine Quality Dataset Results:")

print("Decision Tree:")
print("  Accuracy: {:.4f}".format(acc_dt))
print("  Training Time: {:.6f} seconds".format(dt_train_time))
print("  Prediction Time: {:.6f} seconds".format(dt_predict_time))

print("\nSVM:")
print("  Accuracy: {:.4f}".format(acc_svm))
print("  Training Time: {:.6f} seconds".format(svm_train_time))
print("  Prediction Time: {:.6f} seconds".format(svm_predict_time))

print("\nLinear Discriminant Analysis (LDA):")
print("  Accuracy: {:.4f}".format(acc_lda))
print("  Training Time: {:.6f} seconds".format(lda_train_time))
print("  Prediction Time: {:.6f} seconds".format(lda_predict_time))
# Out:
# Wine Quality Dataset Results:
# Decision Tree:
#   Accuracy: 0.5903
#   Training Time: 0.074481 seconds
#   Prediction Time: 0.002350 seconds
#
# SVM:
#   Accuracy: 0.5585
#   Training Time: 2.105238 seconds
#   Prediction Time: 1.714634 seconds
#
# Linear Discriminant Analysis (LDA):
#   Accuracy: 0.5308
#   Training Time: 0.036508 seconds
#   Prediction Time: 0.000904 seconds

# %%
cv = 5
scores_dt = cross_val_score(dt, scaler.fit_transform(X), y.values.ravel(), cv=cv)
scores_svm = cross_val_score(svm, scaler.fit_transform(X), y.values.ravel(), cv=cv)
scores_lda = cross_val_score(lda, scaler.fit_transform(X), y.values.ravel(), cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Decision Tree CV Accuracy:", scores_dt.mean())
print("SVM CV Accuracy:", scores_svm.mean())
print("LDA CV Accuracy:", scores_lda.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Decision Tree CV Accuracy: 0.3915658198614319
# SVM CV Accuracy: 0.4894787706519808
# LDA CV Accuracy: 0.49224030319180434

# %% [markdown]
# # Adult Census Income Dataset(Decision Tree/Logistic Regression/k-Nearest Neighbors (k-NN))

# %%
adult = fetch_ucirepo(id=2)

X = adult.data.features
y = adult.data.targets

# %%
y
# Out:
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 48837  <=50K.
# 48838  <=50K.
# 48839  <=50K.
# 48840  <=50K.
# 48841   >50K.
#
# [48842 rows x 1 columns]

# %%
X_clean, y_clean = X.dropna(), y.loc[X.dropna().index]

# %%
X_clean
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48836   33           Private  245211  Bachelors             13
# 48837   39           Private  215419  Bachelors             13
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# 2                Divorced  Handlers-cleaners  Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners        Husband
# 4      Married-civ-spouse     Prof-specialty           Wife
# ...                   ...                ...            ...
# 48836       Never-married     Prof-specialty      Own-child
# 48837            Divorced     Prof-specialty  Not-in-family
# 48839  Married-civ-spouse     Prof-specialty        Husband
# 48840            Divorced       Adm-clerical      Own-child
# 48841  Married-civ-spouse    Exec-managerial        Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48836               White    Male             0             0              40
# 48837               White  Female             0             0              36
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country
# 0      United-States
# 1      United-States
# 2      United-States
# 3      United-States
# 4               Cuba
# ...              ...
# 48836  United-States
# 48837  United-States
# 48839  United-States
# 48840  United-States
# 48841  United-States
#
# [47621 rows x 14 columns]

# %%
print(y_clean["income"].unique())
# Out:
# ['<=50K' '>50K' '<=50K.' '>50K.']

# %%
binary_income = y_clean["income"].str.replace(r'\.', '', regex=True)

# %%
binary_income = (binary_income == '>50K').astype(int)

# %%
binary_income
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48836    0
# 48837    0
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 47621, dtype: int64

# %%
categorical_cols = ["workclass", "education", "marital-status", "occupation",
                    "relationship", "race", "sex", "native-country"]

# One-hot encoding
df = pd.get_dummies(X_clean, columns=categorical_cols, drop_first=True)

# %%
df
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 48836   33  245211             13             0             0              40
# 48837   39  215419             13             0             0              36
# 48839   38  374983             13             0             0              50
# 48840   44   83891             13          5455             0              40
# 48841   35  182148             13             0             0              60
#
#        workclass_Federal-gov  workclass_Local-gov  workclass_Never-worked  \
# 0                      False                False                   False
# 1                      False                False                   False
# 2                      False                False                   False
# 3                      False                False                   False
# 4                      False                False                   False
# ...                      ...                  ...                     ...
# 48836                  False                False                   False
# 48837                  False                False                   False
# 48839                  False                False                   False
# 48840                  False                False                   False
# 48841                  False                False                   False
#
#        workclass_Private  ...  native-country_Portugal  \
# 0                  False  ...                    False
# 1                  False  ...                    False
# 2                   True  ...                    False
# 3                   True  ...                    False
# 4                   True  ...                    False
# ...                  ...  ...                      ...
# 48836               True  ...                    False
# 48837               True  ...                    False
# 48839               True  ...                    False
# 48840               True  ...                    False
# 48841              False  ...                    False
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
# ...                           ...                      ...
# 48836                       False                    False
# 48837                       False                    False
# 48839                       False                    False
# 48840                       False                    False
# 48841                       False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 0                     False                  False                    False
# 1                     False                  False                    False
# 2                     False                  False                    False
# 3                     False                  False                    False
# 4                     False                  False                    False
# ...                     ...                    ...                      ...
# 48836                 False                  False                    False
# 48837                 False                  False                    False
# 48839                 False                  False                    False
# 48840                 False                  False                    False
# 48841                 False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 0                               False                          True
# 1                               False                          True
# 2                               False                          True
# 3                               False                          True
# 4                               False                         False
# ...                               ...                           ...
# 48836                           False                          True
# 48837                           False                          True
# 48839                           False                          True
# 48840                           False                          True
# 48841                           False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ...                       ...                        ...
# 48836                   False                      False
# 48837                   False                      False
# 48839                   False                      False
# 48840                   False                      False
# 48841                   False                      False
#
# [47621 rows x 100 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df, binary_income,
                                                    test_size=0.3,
                                                    random_state=42)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Decision Tree ---
dt = DecisionTreeClassifier(random_state=42)

start = time.time()
dt.fit(X_train_scaled, y_train)
dt_train_time = time.time() - start

start = time.time()
y_pred_dt = dt.predict(X_test_scaled)
dt_predict_time = time.time() - start

acc_dt = accuracy_score(y_test, y_pred_dt)

# %%
# --- Logistic Regression ---
lr = LogisticRegression(max_iter=200, random_state=42)

start = time.time()
lr.fit(X_train_scaled, y_train)
lr_train_time = time.time() - start

start = time.time()
y_pred_lr = lr.predict(X_test_scaled)
lr_predict_time = time.time() - start

acc_lr = accuracy_score(y_test, y_pred_lr)

# %%
# --- knn ---
knn = KNeighborsClassifier()
start = time.time()
knn.fit(X_train_scaled, y_train)
knn_train_time = time.time() - start

start = time.time()
y_pred_knn = knn.predict(X_test_scaled)
knn_predict_time = time.time() - start

acc_knn = accuracy_score(y_test, y_pred_knn)

# %%
print("Adult Dataset Results:")

print("Decision Tree:")
print("  Accuracy: {:.4f}".format(acc_dt))
print("  Training Time: {:.6f} seconds".format(dt_train_time))
print("  Prediction Time: {:.6f} seconds".format(dt_predict_time))

print("\nLogistic Regression:")
print("  Accuracy: {:.4f}".format(acc_lr))
print("  Training Time: {:.6f} seconds".format(lr_train_time))
print("  Prediction Time: {:.6f} seconds".format(lr_predict_time))

print("\nknn:")
print("  Accuracy: {:.4f}".format(acc_knn))
print("  Training Time: {:.6f} seconds".format(knn_train_time))
print("  Prediction Time: {:.6f} seconds".format(knn_predict_time))
# Out:
# Adult Dataset Results:
# Decision Tree:
#   Accuracy: 0.8128
#   Training Time: 0.463348 seconds
#   Prediction Time: 0.006180 seconds
#
# Logistic Regression:
#   Accuracy: 0.8478
#   Training Time: 0.371648 seconds
#   Prediction Time: 0.003016 seconds
#
# knn:
#   Accuracy: 0.8194
#   Training Time: 0.018417 seconds
#   Prediction Time: 6.188198 seconds

# %%
cv = 5
scores_1 = cross_val_score(dt, scaler.fit_transform(df), binary_income, cv=cv)
scores_2 = cross_val_score(lr, scaler.fit_transform(df), binary_income, cv=cv)
scores_3 = cross_val_score(knn, scaler.fit_transform(df), binary_income, cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Decision Tree CV Accuracy:", scores_1.mean())
print("Logistic Regression CV Accuracy:", scores_2.mean())
print("k-NN CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Decision Tree CV Accuracy: 0.8137796532258331
# Logistic Regression CV Accuracy: 0.8509901373626072
# k-NN CV Accuracy: 0.8199953767853776

# %% [markdown]
# # Bank Marketing Dataset(Decision Tree/Logistic Regression/Linear Discriminant Analysis (LDA))

# %%
bank_marketing = fetch_ucirepo(id=222)

X = bank_marketing.data.features
y = bank_marketing.data.targets

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day_of_week month  duration  campaign  pdays  previous  \
# 0            NaN            5   may       261         1     -1         0
# 1            NaN            5   may       151         1     -1         0
# 2            NaN            5   may        76         1     -1         0
# 3            NaN            5   may        92         1     -1         0
# 4            NaN            5   may       198         1     -1         0
# ...          ...          ...   ...       ...       ...    ...       ...
# 45206   cellular           17   nov       977         3     -1         0
# 45207   cellular           17   nov       456         2     -1         0
# 45208   cellular           17   nov      1127         5    184         3
# 45209  telephone           17   nov       508         4     -1         0
# 45210   cellular           17   nov       361         2    188        11
#
#       poutcome
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 45206      NaN
# 45207      NaN
# 45208  success
# 45209      NaN
# 45210    other
#
# [45211 rows x 16 columns]

# %%
X = X.drop(columns=["contact", "poutcome"])

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#        day_of_week month  duration  campaign  pdays  previous
# 0                5   may       261         1     -1         0
# 1                5   may       151         1     -1         0
# 2                5   may        76         1     -1         0
# 3                5   may        92         1     -1         0
# 4                5   may       198         1     -1         0
# ...            ...   ...       ...       ...    ...       ...
# 45206           17   nov       977         3     -1         0
# 45207           17   nov       456         2     -1         0
# 45208           17   nov      1127         5    184         3
# 45209           17   nov       508         4     -1         0
# 45210           17   nov       361         2    188        11
#
# [45211 rows x 14 columns]

# %%
X_clean, y_clean = X.dropna(), y.loc[X.dropna().index]

# %%
y_clean = y_clean["y"].apply(lambda x: 1 if x.strip().lower() == 'yes' else 0)

# %%
y_clean
# Out:
# 0        0
# 1        0
# 2        0
# 5        0
# 6        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y, Length: 43193, dtype: int64

# %%
X_encoded = pd.get_dummies(X_clean, drop_first=True)

# %%
X_encoded
# Out:
#        age  balance  day_of_week  duration  campaign  pdays  previous  \
# 0       58     2143            5       261         1     -1         0
# 1       44       29            5       151         1     -1         0
# 2       33        2            5        76         1     -1         0
# 5       35      231            5       139         1     -1         0
# 6       28      447            5       217         1     -1         0
# ...    ...      ...          ...       ...       ...    ...       ...
# 45206   51      825           17       977         3     -1         0
# 45207   71     1729           17       456         2     -1         0
# 45208   72     5715           17      1127         5    184         3
# 45209   57      668           17       508         4     -1         0
# 45210   37     2971           17       361         2    188        11
#
#        job_blue-collar  job_entrepreneur  job_housemaid  ...  month_dec  \
# 0                False             False          False  ...      False
# 1                False             False          False  ...      False
# 2                False              True          False  ...      False
# 5                False             False          False  ...      False
# 6                False             False          False  ...      False
# ...                ...               ...            ...  ...        ...
# 45206            False             False          False  ...      False
# 45207            False             False          False  ...      False
# 45208            False             False          False  ...      False
# 45209             True             False          False  ...      False
# 45210            False              True          False  ...      False
#
#        month_feb  month_jan  month_jul  month_jun  month_mar  month_may  \
# 0          False      False      False      False      False       True
# 1          False      False      False      False      False       True
# 2          False      False      False      False      False       True
# 5          False      False      False      False      False       True
# 6          False      False      False      False      False       True
# ...          ...        ...        ...        ...        ...        ...
# 45206      False      False      False      False      False      False
# 45207      False      False      False      False      False      False
# 45208      False      False      False      False      False      False
# 45209      False      False      False      False      False      False
# 45210      False      False      False      False      False      False
#
#        month_nov  month_oct  month_sep
# 0          False      False      False
# 1          False      False      False
# 2          False      False      False
# 5          False      False      False
# 6          False      False      False
# ...          ...        ...        ...
# 45206       True      False      False
# 45207       True      False      False
# 45208       True      False      False
# 45209       True      False      False
# 45210       True      False      False
#
# [43193 rows x 35 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_clean,
                                                    test_size=0.3,
                                                    random_state=42)

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Decision Tree ---
dt = DecisionTreeClassifier(random_state=42)

start = time.time()
dt.fit(X_train_scaled, y_train)
dt_train_time = time.time() - start

start = time.time()
y_pred_dt = dt.predict(X_test_scaled)
dt_predict_time = time.time() - start

acc_dt = accuracy_score(y_test, y_pred_dt)

# %%
# --- Logistic Regression ---
lr = LogisticRegression(max_iter=200, random_state=42)

start = time.time()
lr.fit(X_train_scaled, y_train)
lr_train_time = time.time() - start

start = time.time()
y_pred_lr = lr.predict(X_test_scaled)
lr_predict_time = time.time() - start

acc_lr = accuracy_score(y_test, y_pred_lr)

# %%
# --- LDA ---
lda = LinearDiscriminantAnalysis()
start = time.time()
lda.fit(X_train_scaled, y_train)
lda_train_time = time.time() - start

start = time.time()
y_pred_lda = lda.predict(X_test_scaled)
lda_predict_time = time.time() - start

acc_lda = accuracy_score(y_test, y_pred_lda)

# %%
print("Bank Dataset Results:")

print("Decision Tree:")
print("  Accuracy: {:.4f}".format(acc_dt))
print("  Training Time: {:.6f} seconds".format(dt_train_time))
print("  Prediction Time: {:.6f} seconds".format(dt_predict_time))

print("\nLogistic Regression:")
print("  Accuracy: {:.4f}".format(acc_lr))
print("  Training Time: {:.6f} seconds".format(lr_train_time))
print("  Prediction Time: {:.6f} seconds".format(lr_predict_time))

print("\nLDA:")
print("  Accuracy: {:.4f}".format(acc_lda))
print("  Training Time: {:.6f} seconds".format(lda_train_time))
print("  Prediction Time: {:.6f} seconds".format(lda_predict_time))
# Out:
# Bank Dataset Results:
# Decision Tree:
#   Accuracy: 0.8713
#   Training Time: 0.282741 seconds
#   Prediction Time: 0.003517 seconds
#
# Logistic Regression:
#   Accuracy: 0.8935
#   Training Time: 0.475942 seconds
#   Prediction Time: 0.001590 seconds
#
# LDA:
#   Accuracy: 0.8915
#   Training Time: 0.121759 seconds
#   Prediction Time: 0.002782 seconds

# %%
cv = 5
scores_1 = cross_val_score(dt, scaler.fit_transform(X_encoded), y_clean.values.ravel(), cv=cv)
scores_2 = cross_val_score(lr, scaler.fit_transform(X_encoded), y_clean.values.ravel(), cv=cv)
scores_3 = cross_val_score(lda, scaler.fit_transform(X_encoded), y_clean.values.ravel(), cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Decision Tree CV Accuracy:", scores_1.mean())
print("Logistic Regression CV Accuracy:", scores_2.mean())
print("LDA CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Decision Tree CV Accuracy: 0.6163927022523493
# Logistic Regression CV Accuracy: 0.7890585002224897
# LDA CV Accuracy: 0.6819359168045339

# %% [markdown]
# # Breast Cancer Wisconsin(Decision Tree/knn/LDA)

# %%
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets

# %%
X
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# 0       0.30010          0.14710     0.2419             0.07871  ...   25.380
# 1       0.08690          0.07017     0.1812             0.05667  ...   24.990
# 2       0.19740          0.12790     0.2069             0.05999  ...   23.570
# 3       0.24140          0.10520     0.2597             0.09744  ...   14.910
# 4       0.19800          0.10430     0.1809             0.05883  ...   22.540
# ..          ...              ...        ...                 ...  ...      ...
# 564     0.24390          0.13890     0.1726             0.05623  ...   25.450
# 565     0.14400          0.09791     0.1752             0.05533  ...   23.690
# 566     0.09251          0.05302     0.1590             0.05648  ...   18.980
# 567     0.35140          0.15200     0.2397             0.07016  ...   25.740
# 568     0.00000          0.00000     0.1587             0.05884  ...    9.456
#
#      texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0       17.33      184.60  2019.0      0.16220       0.66560      0.7119
# 1       23.41      158.80  1956.0      0.12380       0.18660      0.2416
# 2       25.53      152.50  1709.0      0.14440       0.42450      0.4504
# 3       26.50       98.87   567.7      0.20980       0.86630      0.6869
# 4       16.67      152.20  1575.0      0.13740       0.20500      0.4000
# ..        ...         ...     ...          ...           ...         ...
# 564     26.40      166.10  2027.0      0.14100       0.21130      0.4107
# 565     38.25      155.00  1731.0      0.11660       0.19220      0.3215
# 566     34.12      126.70  1124.0      0.11390       0.30940      0.3403
# 567     39.42      184.60  1821.0      0.16500       0.86810      0.9387
# 568     30.37       59.16   268.6      0.08996       0.06444      0.0000
#
#      concave_points3  symmetry3  fractal_dimension3
# 0             0.2654     0.4601             0.11890
# 1             0.1860     0.2750             0.08902
# 2             0.2430     0.3613             0.08758
# 3             0.2575     0.6638             0.17300
# 4             0.1625     0.2364             0.07678
# ..               ...        ...                 ...
# 564           0.2216     0.2060             0.07115
# 565           0.1628     0.2572             0.06637
# 566           0.1418     0.2218             0.07820
# 567           0.2650     0.4087             0.12400
# 568           0.0000     0.2871             0.07039
#
# [569 rows x 30 columns]

# %%
y
# Out:
#     Diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
y = y["Diagnosis"].apply(lambda x: 1 if x.strip() == 'M' else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# --- Decision Tree ---
dt = DecisionTreeClassifier(random_state=42)
start = time.time()
dt.fit(X_train, y_train)
dt_train_time = time.time() - start

start = time.time()
y_pred_dt = dt.predict(X_test)
dt_predict_time = time.time() - start

acc_dt = accuracy_score(y_test, y_pred_dt)

# %%
# --- knn ---
knn = KNeighborsClassifier()
start = time.time()
knn.fit(X_train_scaled, y_train)
knn_train_time = time.time() - start

start = time.time()
y_pred_knn = knn.predict(X_test_scaled)
knn_predict_time = time.time() - start

acc_knn = accuracy_score(y_test, y_pred_knn)

# %%
# --- LDA ---
lda = LinearDiscriminantAnalysis()
start = time.time()
lda.fit(X_train_scaled, y_train)
lda_train_time = time.time() - start

start = time.time()
y_pred_lda = lda.predict(X_test_scaled)
lda_predict_time = time.time() - start

acc_lda = accuracy_score(y_test, y_pred_lda)

# %%
print("Breast Cancer Wisconsin Dataset Results:\n")

print("Decision Tree:")
print("  Accuracy: {:.4f}".format(acc_dt))
print("  Training Time: {:.6f} seconds".format(dt_train_time))
print("  Prediction Time: {:.6f} seconds".format(dt_predict_time))

print("\nk-Nearest Neighbors (k-NN):")
print("  Accuracy: {:.4f}".format(acc_knn))
print("  Training Time: {:.6f} seconds".format(knn_train_time))
print("  Prediction Time: {:.6f} seconds".format(knn_predict_time))

print("\nLinear Discriminant Analysis (LDA):")
print("  Accuracy: {:.4f}".format(acc_lda))
print("  Training Time: {:.6f} seconds".format(lda_train_time))
print("  Prediction Time: {:.6f} seconds".format(lda_predict_time))
# Out:
# Breast Cancer Wisconsin Dataset Results:
#
# Decision Tree:
#   Accuracy: 0.9415
#   Training Time: 0.015232 seconds
#   Prediction Time: 0.002825 seconds
#
# k-Nearest Neighbors (k-NN):
#   Accuracy: 0.9591
#   Training Time: 0.001980 seconds
#   Prediction Time: 0.016369 seconds
#
# Linear Discriminant Analysis (LDA):
#   Accuracy: 0.9532
#   Training Time: 0.041768 seconds
#   Prediction Time: 0.000605 seconds

# %%
scores_1 = cross_val_score(dt, scaler.fit_transform(X), y.values.ravel(), cv=cv)
scores_2 = cross_val_score(knn, scaler.fit_transform(X), y.values.ravel(), cv=cv)
scores_3 = cross_val_score(lda, scaler.fit_transform(X), y.values.ravel(), cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Decision Tree CV Accuracy:", scores_1.mean())
print("k-NN CV Accuracy:", scores_2.mean())
print("LDA CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Decision Tree CV Accuracy: 0.9173420276354604
# k-NN CV Accuracy: 0.9648501785437045
# LDA CV Accuracy: 0.9595870206489675

# %% [markdown]
# # Mushroom(Support Vector Machine (SVM)/Logistic Regression/k-Nearest Neighbors (k-NN))

# %%
mushroom = fetch_ucirepo(id=73)

X = mushroom.data.features
y = mushroom.data.targets

# %%
X
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# 2               c         b          n           e  ...
# 3               c         n          n           e  ...
# 4               w         b          k           t  ...
# ...           ...       ...        ...         ...  ...
# 8119            c         b          y           e  ...
# 8120            c         b          y           e  ...
# 8121            c         b          n           e  ...
# 8122            c         n          b           t  ...
# 8123            c         b          y           e  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                           s                      w                      w
# 1                           s                      w                      w
# 2                           s                      w                      w
# 3                           s                      w                      w
# 4                           s                      w                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 0            p          w           o         p                 k          s
# 1            p          w           o         p                 n          n
# 2            p          w           o         p                 n          n
# 3            p          w           o         p                 k          s
# 4            p          w           o         e                 n          a
# ...        ...        ...         ...       ...               ...        ...
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      habitat
# 0          u
# 1          g
# 2          m
# 3          u
# 4          g
# ...      ...
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [8124 rows x 22 columns]

# %%
X_clean, y_clean = X.dropna(), y.loc[X.dropna().index]

# %%
y_clean
# Out:
#      poisonous
# 0            p
# 1            e
# 2            e
# 3            p
# 4            e
# ...        ...
# 7986         e
# 8001         e
# 8038         e
# 8095         p
# 8114         p
#
# [5644 rows x 1 columns]

# %%
y_clean = y_clean["poisonous"].apply(lambda x: 1 if x.strip() == 'p' else 0)

# %%
X_encoded = pd.get_dummies(X_clean, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_clean, test_size=0.3, random_state=42
)

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#---SVM---
svm = SVC(kernel='rbf', random_state=42)

start = time.time()
svm.fit(X_train_scaled, y_train)
svm_train_time = time.time() - start

start = time.time()
y_pred_svm = svm.predict(X_test_scaled)
svm_predict_time = time.time() - start

acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
#---LR---
lr = LogisticRegression(max_iter=500, random_state=42)

start = time.time()
lr.fit(X_train_scaled, y_train)
lr_train_time = time.time() - start

start = time.time()
y_pred_lr = lr.predict(X_test_scaled)
lr_predict_time = time.time() - start

acc_lr = accuracy_score(y_test, y_pred_lr)

# %%
#---knn---
knn = KNeighborsClassifier()

start = time.time()
knn.fit(X_train_scaled, y_train)
knn_train_time = time.time() - start

start = time.time()
y_pred_knn = knn.predict(X_test_scaled)
knn_predict_time = time.time() - start

acc_knn = accuracy_score(y_test, y_pred_knn)

# %%
print("Mushroom Dataset Results:\n")

print("SVM:")
print("  Accuracy: {:.4f}".format(acc_svm))
print("  Training Time: {:.6f} seconds".format(svm_train_time))
print("  Prediction Time: {:.6f} seconds".format(svm_predict_time))

print("\nLogistic Regression:")
print("  Accuracy: {:.4f}".format(acc_lr))
print("  Training Time: {:.6f} seconds".format(lr_train_time))
print("  Prediction Time: {:.6f} seconds".format(lr_predict_time))

print("\nk-Nearest Neighbors (k-NN):")
print("  Accuracy: {:.4f}".format(acc_knn))
print("  Training Time: {:.6f} seconds".format(knn_train_time))
print("  Prediction Time: {:.6f} seconds".format(knn_predict_time))
# Out:
# Mushroom Dataset Results:
#
# SVM:
#   Accuracy: 1.0000
#   Training Time: 0.421185 seconds
#   Prediction Time: 0.157484 seconds
#
# Logistic Regression:
#   Accuracy: 1.0000
#   Training Time: 0.013001 seconds
#   Prediction Time: 0.000722 seconds
#
# k-Nearest Neighbors (k-NN):
#   Accuracy: 0.9994
#   Training Time: 0.002522 seconds
#   Prediction Time: 0.175064 seconds

# %%
scores_1 = cross_val_score(svm, scaler.fit_transform(X_encoded), y_clean, cv=cv)
scores_2 = cross_val_score(lr, scaler.fit_transform(X_encoded), y_clean, cv=cv)
scores_3 = cross_val_score(knn, scaler.fit_transform(X_encoded), y_clean, cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("SVM CV Accuracy:", scores_1.mean())
print("Logistic Regression CV Accuracy:", scores_2.mean())
print("k-NN CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# SVM CV Accuracy: 0.9376288562651942
# Logistic Regression CV Accuracy: 0.9376288562651942
# k-NN CV Accuracy: 0.9553515004177424

# %% [markdown]
# # Car Evaluation(SVM/Logistic Regresssion/LDA)

# %%
abalone = fetch_ucirepo(id=19)

X = abalone.data.features
y = abalone.data.targets

# %%
X
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %%
X_encoded = pd.get_dummies(X, drop_first=True)

# %%
y.value_counts()
# Out:
# class
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
y["class"] = y["class"].replace({"unacc": 0, "acc": 1, "good": 2, "vgood": 3})
# Out:
# <ipython-input-194-eea155b371a1>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y["class"] = y["class"].replace({"unacc": 0, "acc": 1, "good": 2, "vgood": 3})
# <ipython-input-194-eea155b371a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["class"] = y["class"].replace({"unacc": 0, "acc": 1, "good": 2, "vgood": 3})

# %%
y
# Out:
#       class
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 1723      2
# 1724      3
# 1725      0
# 1726      2
# 1727      3
#
# [1728 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.3, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#---SVM---
svm = SVC(kernel='rbf', random_state=42)

start = time.time()
svm.fit(X_train_scaled, y_train.values.ravel())
svm_train_time = time.time() - start

start = time.time()
y_pred_svm = svm.predict(X_test_scaled)
svm_predict_time = time.time() - start

acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
# --- Logistic Regression ---
lr = LogisticRegression(max_iter=300, random_state=42)

start = time.time()
lr.fit(X_train_scaled, y_train.values.ravel())
lr_train_time = time.time() - start

start = time.time()
y_pred_lr = lr.predict(X_test_scaled)
lr_predict_time = time.time() - start

acc_lr = accuracy_score(y_test, y_pred_lr)

# %%
# --- Linear Discriminant Analysis (LDA) ---
lda = LinearDiscriminantAnalysis()
start = time.time()
lda.fit(X_train_scaled, y_train.values.ravel())
lda_train_time = time.time() - start

start = time.time()
y_pred_lda = lda.predict(X_test_scaled)
lda_predict_time = time.time() - start

acc_lda = accuracy_score(y_test, y_pred_lda)

# %%
print("Car Evaluation Dataset Results:\n")

print("SVM:")
print("  Accuracy: {:.4f}".format(acc_svm))
print("  Training Time: {:.6f} seconds".format(svm_train_time))
print("  Prediction Time: {:.6f} seconds".format(svm_predict_time))

print("\nLogistic Regression:")
print("  Accuracy: {:.4f}".format(acc_lr))
print("  Training Time: {:.6f} seconds".format(lr_train_time))
print("  Prediction Time: {:.6f} seconds".format(lr_predict_time))

print("\nLinear Discriminant Analysis (LDA):")
print("  Accuracy: {:.4f}".format(acc_lda))
print("  Training Time: {:.6f} seconds".format(lda_train_time))
print("  Prediction Time: {:.6f} seconds".format(lda_predict_time))
# Out:
# Car Evaluation Dataset Results:
#
# SVM:
#   Accuracy: 0.9422
#   Training Time: 0.112448 seconds
#   Prediction Time: 0.040877 seconds
#
# Logistic Regression:
#   Accuracy: 0.9152
#   Training Time: 0.034859 seconds
#   Prediction Time: 0.001076 seconds
#
# Linear Discriminant Analysis (LDA):
#   Accuracy: 0.8940
#   Training Time: 0.124354 seconds
#   Prediction Time: 0.000661 seconds

# %%
scores_1 = cross_val_score(svm, scaler.fit_transform(X_encoded), y.values.ravel(), cv=cv)
scores_2 = cross_val_score(lr, scaler.fit_transform(X_encoded), y.values.ravel(), cv=cv)
scores_3 = cross_val_score(lda, scaler.fit_transform(X_encoded), y.values.ravel(), cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("SVM CV Accuracy:", scores_1.mean())
print("Logistic Regression CV Accuracy:", scores_2.mean())
print("LDA CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# SVM CV Accuracy: 0.7355097595710814
# Logistic Regression CV Accuracy: 0.7551662896875262
# LDA CV Accuracy: 0.558668007036944

# %% [markdown]
# # Heart Disease(Support Vector Machine/k-Nearest Neighbors (k-NN)/LDA)

# %%
heart_disease = fetch_ucirepo(id=45)

X = heart_disease.data.features
y = heart_disease.data.targets

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal
# 0        3  0.0   6.0
# 1        2  3.0   3.0
# 2        2  2.0   7.0
# 3        3  0.0   3.0
# 4        1  0.0   3.0
# ..     ...  ...   ...
# 298      2  0.0   7.0
# 299      2  2.0   7.0
# 300      2  1.0   7.0
# 301      2  1.0   3.0
# 302      1  NaN   3.0
#
# [303 rows x 13 columns]

# %%
y.value_counts()
# Out:
# num
# 0      164
# 1       55
# 2       36
# 3       35
# 4       13
# Name: count, dtype: int64

# %%
y = y["num"].apply(lambda x: 1 if int(x) > 0 else 0)

# %%
X_clean, y_clean = X.dropna(), y.loc[X.dropna().index]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_clean, y_clean, test_size=0.3, random_state=42
)

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
svm = SVC(kernel='rbf', random_state=42)
start = time.time()
svm.fit(X_train_scaled, y_train)
svm_train_time = time.time() - start

start = time.time()
y_pred_svm = svm.predict(X_test_scaled)
svm_predict_time = time.time() - start

acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
knn = KNeighborsClassifier()
start = time.time()
knn.fit(X_train_scaled, y_train)
knn_train_time = time.time() - start

start = time.time()
y_pred_knn = knn.predict(X_test_scaled)
knn_predict_time = time.time() - start

acc_knn = accuracy_score(y_test, y_pred_knn)

# %%
lda = LinearDiscriminantAnalysis()
start = time.time()
lda.fit(X_train_scaled, y_train)
lda_train_time = time.time() - start

start = time.time()
y_pred_lda = lda.predict(X_test_scaled)
lda_predict_time = time.time() - start

acc_lda = accuracy_score(y_test, y_pred_lda)

# %%
print("Heart Disease (Cleveland) Dataset Results (Binary Classification):\n")

print("SVM:")
print("  Accuracy: {:.4f}".format(acc_svm))
print("  Training Time: {:.6f} seconds".format(svm_train_time))
print("  Prediction Time: {:.6f} seconds".format(svm_predict_time))

print("\nk-Nearest Neighbors (k-NN):")
print("  Accuracy: {:.4f}".format(acc_knn))
print("  Training Time: {:.6f} seconds".format(knn_train_time))
print("  Prediction Time: {:.6f} seconds".format(knn_predict_time))

print("\nLinear Discriminant Analysis (LDA):")
print("  Accuracy: {:.4f}".format(acc_lda))
print("  Training Time: {:.6f} seconds".format(lda_train_time))
print("  Prediction Time: {:.6f} seconds".format(lda_predict_time))
# Out:
# Heart Disease (Cleveland) Dataset Results (Binary Classification):
#
# SVM:
#   Accuracy: 0.8889
#   Training Time: 0.005077 seconds
#   Prediction Time: 0.001366 seconds
#
# k-Nearest Neighbors (k-NN):
#   Accuracy: 0.8444
#   Training Time: 0.002003 seconds
#   Prediction Time: 0.012439 seconds
#
# Linear Discriminant Analysis (LDA):
#   Accuracy: 0.9000
#   Training Time: 0.003785 seconds
#   Prediction Time: 0.000647 seconds

# %%
scores_1 = cross_val_score(svm, scaler.fit_transform(X_clean), y_clean.values.ravel(), cv=cv)
scores_2 = cross_val_score(knn, scaler.fit_transform(X_clean), y_clean.values.ravel(), cv=cv)
scores_3 = cross_val_score(lda, scaler.fit_transform(X_clean), y_clean.values.ravel(), cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("SVM CV Accuracy:", scores_1.mean())
print("k-NN CV Accuracy:", scores_2.mean())
print("LDA CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# SVM CV Accuracy: 0.8212429378531073
# k-NN CV Accuracy: 0.8348022598870056
# LDA CV Accuracy: 0.83135593220339

# %% [markdown]
# # Spambase(Logistic Regression/k-Nearest Neighbors (k-NN)/LDA)

# %%
spambase = fetch_ucirepo(id=94)
X = spambase.data.features
y = spambase.data.targets

# %%
X
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4596           0.00            0.31              0.00                0.00
# 4597           0.00            0.00              0.00                0.00
# 4598           0.00            0.00              0.00                0.00
# 4599           0.32            0.00              0.00                0.00
# 4600           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 0                0.00            0.00  ...                   0.0        0.000
# 1                0.00            0.94  ...                   0.0        0.000
# 2                0.64            0.25  ...                   0.0        0.010
# 3                0.31            0.63  ...                   0.0        0.000
# 4                0.31            0.63  ...                   0.0        0.000
# ...               ...             ...  ...                   ...          ...
# 4596             0.00            0.00  ...                   0.0        0.000
# 4597             0.00            0.00  ...                   0.0        0.000
# 4598             0.00            0.00  ...                   0.0        0.102
# 4599             0.00            0.00  ...                   0.0        0.000
# 4600             0.00            0.00  ...                   0.0        0.000
#
#       char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0           0.000          0.0        0.778        0.000        0.000
# 1           0.132          0.0        0.372        0.180        0.048
# 2           0.143          0.0        0.276        0.184        0.010
# 3           0.137          0.0        0.137        0.000        0.000
# 4           0.135          0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...          ...
# 4596        0.232          0.0        0.000        0.000        0.000
# 4597        0.000          0.0        0.353        0.000        0.000
# 4598        0.718          0.0        0.000        0.000        0.000
# 4599        0.057          0.0        0.000        0.000        0.000
# 4600        0.000          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total
# 0                          278
# 1                         1028
# 2                         2259
# 3                          191
# 4                          191
# ...                        ...
# 4596                        88
# 4597                        14
# 4598                       118
# 4599                        78
# 4600                        40
#
# [4601 rows x 57 columns]

# %%
y
# Out:
#       Class
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 4596      0
# 4597      0
# 4598      0
# 4599      0
# 4600      0
#
# [4601 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
y_train.shape
# Out:
# (3220, 1)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LogisticRegression(max_iter=1000, random_state=42)
start = time.time()
lr.fit(X_train_scaled, y_train.values.ravel())
lr_train_time = time.time() - start

start = time.time()
y_pred_lr = lr.predict(X_test_scaled)
lr_predict_time = time.time() - start

acc_lr = accuracy_score(y_test, y_pred_lr)

# %%
knn = KNeighborsClassifier()
start = time.time()
knn.fit(X_train_scaled, y_train.values.ravel())
knn_train_time = time.time() - start

start = time.time()
y_pred_knn = knn.predict(X_test_scaled)
knn_predict_time = time.time() - start

acc_knn = accuracy_score(y_test, y_pred_knn)

# %%
lda = LinearDiscriminantAnalysis()
start = time.time()
lda.fit(X_train_scaled, y_train.values.ravel())
lda_train_time = time.time() - start

start = time.time()
y_pred_lda = lda.predict(X_test_scaled)
lda_predict_time = time.time() - start

acc_lda = accuracy_score(y_test, y_pred_lda)

# %%
print("Spambase Dataset Results:\n")

print("Logistic Regression:")
print("  Accuracy: {:.4f}".format(acc_lr))
print("  Training Time: {:.6f} seconds".format(lr_train_time))
print("  Prediction Time: {:.6f} seconds".format(lr_predict_time))

print("\nk-Nearest Neighbors (k-NN):")
print("  Accuracy: {:.4f}".format(acc_knn))
print("  Training Time: {:.6f} seconds".format(knn_train_time))
print("  Prediction Time: {:.6f} seconds".format(knn_predict_time))

print("\nLinear Discriminant Analysis (LDA):")
print("  Accuracy: {:.4f}".format(acc_lda))
print("  Training Time: {:.6f} seconds".format(lda_train_time))
print("  Prediction Time: {:.6f} seconds".format(lda_predict_time))
# Out:
# Spambase Dataset Results:
#
# Logistic Regression:
#   Accuracy: 0.9232
#   Training Time: 0.026182 seconds
#   Prediction Time: 0.000641 seconds
#
# k-Nearest Neighbors (k-NN):
#   Accuracy: 0.8965
#   Training Time: 0.002407 seconds
#   Prediction Time: 0.102890 seconds
#
# Linear Discriminant Analysis (LDA):
#   Accuracy: 0.8863
#   Training Time: 0.021097 seconds
#   Prediction Time: 0.000809 seconds

# %%
scores_1 = cross_val_score(lr, scaler.fit_transform(X), y.values.ravel(), cv=cv)
scores_2 = cross_val_score(knn, scaler.fit_transform(X), y.values.ravel(), cv=cv)
scores_3 = cross_val_score(lda, scaler.fit_transform(X), y.values.ravel(), cv=cv)

print("\nCross-Validation Mean Accuracy (5 folds):")
print("Logistic Regression CV Accuracy:", scores_1.mean())
print("k-NN CV Accuracy:", scores_2.mean())
print("LDA CV Accuracy:", scores_3.mean())
# Out:
# Cross-Validation Mean Accuracy (5 folds):
# Logistic Regression CV Accuracy: 0.9113220507010338
# k-NN CV Accuracy: 0.8837197280838407
# LDA CV Accuracy: 0.8795933059528867
